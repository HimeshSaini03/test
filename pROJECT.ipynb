# %%
name=input("Enter your Name:")
R=int(input("Enter your roll Number:"))
print("Let's start ")
print("Select Quiz type: 1=Python 2=Gk 3=History")
x=int(input())
points=0
list=[]
if x==1:
    print("Python Quiz")
    print("Total of 10 Question will be there")
    print("->Each Question Hold 5 Points")
    print("->All The best")
elif x==2:
    print("GK Quiz")
    print("Python Quiz")
    print("Total of 10 Question will be there")
    print("->Each Question Hold 5 Points")
    print("->All The best")
elif x==3:
    print("History Quiz")
    print("Python Quiz")
    print("Total of 10 Question will be there")
    print("->Each Question Hold 5 Points")
    print("->All The best")
else :
    print("Topic Not selected")

    
if x==3:
    print("Q1-Taj Mahal is located in which city of india:")
    A=input("Your Answer:")
    print("Correct Answer:Agra")
    if A == "Agra":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    print("Q2-How many years United Kingdom ruled INDIA:")
    B=input("Your Answer:")
    print("Correct Answer:200")
    if B=="200":
        list.append(B)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    print("Your Answers :",list)
# Out:
# Enter your Name:HEMNAG
# Enter your roll Number:5
# Let's start
# Select Quiz type: 1=Python 2=Gk 3=History
# 3
# History Quiz
# Python Quiz
# Total of 10 Question will be there
# ->Each Question Hold 5 Points
# ->All The best
# Q1-Taj Mahal is located in which city of india:
# Your Answer:Agra
# Correct Answer:Agra
# Well Done! You are awarded 5 points
# Total Points: 5
# Q2-How many years United Kingdom ruled INDIA:
# Your Answer:200
# Correct Answer:200
# Well Done! You are awarded 5 points
# Total Points: 10
# Your Answers : ['Agra', '200']

# %%
print("Q-:")
    A=input("Your Answer:")
    print("Correct Answer:")
    if A == "":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)

# %%
name=input("Enter your Name:")
R=int(input("Enter your roll Number:"))
print("Let's start ")
print("Select Your Choice : 1=Python Quiz Game 2=Calculator 3=Empty")
x=int(input("You Selected->"))
points=0
list=[]
if x==1:
    print('''Python Quiz
    ->Total of 10 Question will be there
    ->Type only option Letter
    ->Each Question Hold 5 Points
    ->All The best''')
elif x==2:
    print('''Your CALCULATOR is ready
    For ADDITION TYPE 1
    FOR SUBTRACTION TYPE 2
    FOR MULTIPLICATION TYPE 3
    FOR DIVISION TYPE 4
    FOR MUDULUD TYPE 5''')
elif x==3:
    print('''History Quiz
    ->Total of 10 Question will be there
    ->Type only option Letter
    ->Each Question Hold 5 Points
    ->All The best''')
else :
    print('''Topic Not selected
            Please Start Again''')
if x==1:
    print('''Q1-Who developed Python Programming Language?:
    a) Wick van Rossum
    b) Rasmus Lerdorf
    c) Guido van Rossum
    d) Niene Stom''')
    A=input("Your Answer:")
    print("Correct Answer:c) Guido van Rossum")
    if A == "c":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    
    print('''Q2-Which type of Programming does Python support?
    a) object-oriented programming
    b) structured programming
    c) functional programming
    d) all of the mentioned:''')
    A=input("Your Answer:")
    print("Correct Answer:d) all of the mentioned")
    if A == "d":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    
    
    print('''Q3-Is Python case sensitive when dealing with identifiers?
    a) no
    b) yes
    c) machine dependent
    d) none of the mentioned:''')
    A=input("Your Answer:")
    print("Correct Answer:a) no")
    if A == "a":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    
    print('''Q4-:Which of the following is the correct extension of the Python file?
    a) .python
    b) .pl
    c) .py
    d) .p''')
    A=input("Your Answer:")
    print("Correct Answer:c) .py")
    if A == "c":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
    print('''Q5-Which of the following is used to define a block of code in Python language?
    a) Indentation
    b) Key
    c) Brackets
    d) All of the mentioned:''')
    A=input("Your Answer:")
    print("Correct Answer:a) Indentation")
    if A == "a":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
    print('''Q6-Which keyword is used for function in Python language?
    a) Function
    b) Def
    c) Fun
    d) Define:''')
    A=input("Your Answer:")
    print("Correct Answer:b) Def")
    if A == "b":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
    print('''Q7-Which of the following functions is a built-in function in python?
    a) factorial()
    b) print()
    c) seed()
    d) sqrt():''')
    A=input("Your Answer:")
    print("Correct Answer:b) print()")
    if A == "b":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
    print('''Q8-Which of the following is the use of id() function in python?
    a) Every object doesn’t have a unique id
    b) Id returns the identity of the object
    c) All of the mentioned
    d) None of the mentioned:''')
    A=input("Your Answer:")
    print("Correct Answer:b) Id returns the identity of the object")
    if A == "b":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
        
    print('''Q9- What will be the output of the following Python function?
                            len(["hello",2, 4, 6])
    a) Error
    b) 6
    c) 4
    d) 3:''')
    A=input("Your Answer:")
    print("Correct Answer:c) 4")
    if A == "":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
        
    print('''Q10- What will be the output of the following Python code snippet?
                          for i in [1, 2, 3, 4][::-1]:
                          print (i)
    a) 4 3 2 1
    b) error
    c) 1 2 3 4
    d) none of the mentioned:''')
    A=input("Your Answer:")
    print("Correct Answer:a) 4 3 2 1")
    if A == "a":
        list.append(A)
        print("Well Done! You are awarded 5 points")
        points=points+5
        print("Total Points:",points)
    else:
        print("Incorrect answer")
        print("Total Points:",points)
    
    if points==50:
        print("WOW!!You Are Awesome...You have build up concept of python very strongly ")
    if points==45:
        print("Nice!!Good Job .. But more Clearity in Concepts needed")
    if points==40:
        print("Nice!!Good Job .. But more Clearity in Concepts needed")
    if points==35:
        print("Need more Focus on Concepts")
    if points==30:
        print("Need more Focus on Concepts")
    if points==25:
        print("Poor Concepts!!")
    if points==20:
        print("Poor Concepts!!")
    if points==15:
        print("Poor Concepts!!")
    if points==10:
        print("Poor Concepts!!")
    if points==5:
        print("Poor Concepts!!")
    if points==0:
        print("Tu kar kya raha hai yaar!!rehne de")
    else:
        print("Wanna Try Again")

#CALCULATOR
if x==2:
    OP=int(input("Select the Operation you want to do: "))
    if OP==1:
        num1=int(input("Enter First Number for Addition: "))
        num2=int(input("Enter Second Number for Addition: "))
        add=num1+num2
        print(add)
    if OP==2:
        num1=int(input("Enter First Number for Subtraction: "))
        num2=int(input("Enter Second Number for Subtraction: "))
        sub=num1-num2
        print(sub)
    if OP==3:
        num1=int(input("Enter First Number for Multiplication:"))
        num2=int(input("Enter Second Number For Multiplication:"))
        mul=num1*num2
        print(mul)
    if OP==4:
        num1=int(input("Enter First Number for Division:"))
        num2=int(input("Enter Second Number Division:"))
        div=num1/num2
        print(div)
    if OP==5:
        num1=int(input("Enter First Number (Dividend):"))
        num2=int(input("Enter Second Number(Divisor):"))
        mod=num1%num2
        print("Remainder:",mod)
print("Got Your Solution correct!!That's How it's Work")

# %%
name=input("Enter your Name:")
R=int(input("Enter your roll Number:"))
print("Let's start ")
print("Select Game type: 1=Python Game 2=CALCULATOR 3=History")
x=int(input("You Selected->"))
points=0
list=[]
if x==1:
    print('''Python Quiz Game
    ->Total of 10 Question will be there
    ->Type only option Letter
    ->Each Question Hold 5 Points
    ->All The best''')
elif x==2:
     print("CALCULATOR")
elif x==3:
    print('''History Quiz
    ->Total of 10 Question will be there
    ->Type only option Letter
    ->Each Question Hold 5 Points
    ->All The best''')
else :
    print('''Topic Not selected
            Please Start Again''')
if x==2:
    print('''Your CALCULATOR is ready
    For ADDITION TYPE 1
    FOR SUBTRACTION TYPE 2
    FOR MULTIPLICATION TYPE 3
    FOR DIVISION TYPE 4
    FOR MUDULUD TYPE 5''')
    OP=int(input("Select the Operation you want to do: "))
    if OP==1:
        num1=int(input("Enter First Number:"))
        num2=int(input("Enter Second Number:"))
        add=num1+num2
        print(add)
    if OP==2:
        num1=int(input("Enter First Number:"))
        num2=int(input("Enter Second Number:"))
        sub=num1-num2
        print(sub)
    if OP==3:
        num1=int(input("Enter First Number:"))
        num2=int(input("Enter Second Number:"))
        mul=num1*num2
        print(mul)
    if OP==4:
        num1=int(input("Enter First Number:"))
        num2=int(input("Enter Second Number:"))
        div=num1/num2
        print(div)
    if OP==5:
        num1=int(input("Enter First Number:"))
        num2=int(input("Enter Second Number:"))
        mod=num1%num2
        print("Remainder:",mod)

# %%
#letter Maker
print("Your detail only:->")

A=input("Enter Reciver Name: ")
B=input("Enter The recivers House Address: ")
C=input("Enter The recivers City,state: ")
D=input("Enter Your Name: ")
E=input("Enter Your House Address: ")
F=input("Enter Your City,State: ")
G=input("Enter The occasion: ")
x=input("Enter Occasion date (dd/mm/yyyy): ")
H=input("Enter The Venue Of occasion: ")
print(''' 
       
         ''')

print('To-')
print(A)
print(B)
print(C)
print('''
         ''')
print('From-')
print(D)
print('Address',E,)
print(F)
print(''' ''')

print("Invitation for ",G,)
print(''' ''')
print("Dear",A,)
print('''  ''')
print( "We are Glad to invite you to" ,G, "on the date",x,)
print('''I have arranged a small party on that day
I would earnestly request you to join  ''')
print("There will be lots of fun in the party")
print("We look forward to your presence along with your family at",H,)
print( '''Rest when we meet
                           ''')
       
print("Your affectionately")
print(D)
# Out:
# Your detail only:->
# Enter Reciver Name: Bhavneet
# Enter The recivers House Address: sdg
# Enter The recivers City,state: wdgf
# Enter Your Name: Himesh
# Enter Your House Address: sdgfv
# Enter Your City,State: efgv
# Enter The occasion: Birthday
# Enter Occasion date (dd/mm/yyyy): 03/03/2022
# Enter The Venue Of occasion: Our Residence
#
#
#
# To-
# Bhavneet
# sdg
# wdgf
#
#
# From-
# Himesh
# Address sdgfv
# efgv
#
# Invitation for  Birthday
#
# Dear Bhavneet
#
# We are Glad to invite you to Birthday on the date 03/03/2022
# I have arranged a small party on that day
# I would earnestly request you to join the party
# There will be lots of fun in the party
# We look forward to your presence along with your family at Our Residence
# Rest when we meet
#
# Your affectionately
# Himesh
